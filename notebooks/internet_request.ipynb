# %%
# Импорты стандартной библиотеки
import logging

from serpapi import GoogleSearch
from src.utils.check_serp_response import APIKeyManager

# Локальные импорты
from src.utils.paths import ROOT_DIR

# Настройка логирования
logging.basicConfig(
    level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s"
)
logger = logging.getLogger(__name__)

serpapi_key_manager = APIKeyManager(path_to_file="api_keys_status.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 5
#       2 import logging
#       4 from serpapi import GoogleSearch
# ----> 5 from src.utils.check_serp_response import APIKeyManager
#       7 # Локальные импорты
#       8 from src.utils.paths import ROOT_DIR
#
# ModuleNotFoundError: No module named 'src'

# %%
from pathlib import Path

# Задайте путь к корневой папке вашего проекта
ROOT_DIR = Path("./")
print("Корневая папка проекта:", ROOT_DIR)
# Out:
# Корневая папка проекта: .

# %%
import os

ROOT_DIR = os.path.abspath("../")
print("Корневая папка проекта:", ROOT_DIR)
# Out:
# Корневая папка проекта: /Users/askarembulatov/Digital-Assistant-First

# %%
import os

ROOT_DIR = os.path.abspath(os.path.join(os.getcwd(), ".."))
print("Корневая папка проекта:", ROOT_DIR)
# Out:
# Корневая папка проекта: /Users/askarembulatov/Digital-Assistant-First

# %%
ROOT_DIR
# Out:
# '/Users/askarembulatov/Digital-Assistant-First'

# %%
import os
import sys

# Если ноутбук запущен из корня проекта:
ROOT_DIR = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Или, если корень проекта отличается, укажите путь явно:
# ROOT_DIR = os.path.abspath("/path/to/your/project")

# Добавляем корневую папку в sys.path, если её там ещё нет
if ROOT_DIR not in sys.path:
    sys.path.insert(0, ROOT_DIR)

print("Корневая папка проекта:", ROOT_DIR)
# Out:
# Корневая папка проекта: /Users/askarembulatov/Digital-Assistant-First

# %%
# Импорты стандартной библиотеки
import logging
import os

from serpapi import GoogleSearch
from src.utils.check_serp_response import APIKeyManager
from src.utils.paths import ROOT_DIR

# Настройка логирования
logging.basicConfig(
    level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s"
)
logger = logging.getLogger(__name__)

# Формирование пути к файлу с ключами относительно корневой папки проекта
KEYS_PATH = os.path.join(ROOT_DIR, "api_keys_status.xlsx")

# Инициализация менеджера ключей
serpapi_key_manager = APIKeyManager(path_to_file=KEYS_PATH)
# Out:
#            Name                      Email  \
# 0    SERP_KEY_1                      test5
# 1    SERP_KEY_2  test6test6test6@proton.me
# 2    SERP_KEY_3  test7test7test7@proton.me
# 3    SERP_KEY_4  test8test8test8@proton.me
# 4    SERP_KEY_5         test11test11test11
# 5    SERP_KEY_6            test9test9test9
# 6    SERP_KEY_7            test5test5test5
# 7    SERP_KEY_8            test4test4test4
# 8    SERP_KEY_9         test13test13test13
# 9   SERP_KEY_10         test14test14test14
# 10  SERP_KEY_11         test61test61test61
# 11  SERP_KEY_12         test62test62test62
# 12  SERP_KEY_13         test63test63test63
# 13  SERP_KEY_14         test64test64test64
# 14  SERP_KEY_15         test65test65test65
# 15  SERP_KEY_16         test66test66test66
# 16  SERP_KEY_17         test67test67test67
# 17  SERP_KEY_18              test1@msut.me
# 18  SERP_KEY_19              test3@msut.me
# 19  SERP_KEY_20              test4@msut.me
#
# ...

# %%
from src.utils.check_serp_response import APIKeyManager

api_key_manager = APIKeyManager(path_to_file=KEYS_PATH)
best_key_name, best_key = api_key_manager.get_best_api_key()
# Out:
#            Name                      Email  \
# 0    SERP_KEY_1                      test5
# 1    SERP_KEY_2  test6test6test6@proton.me
# 2    SERP_KEY_3  test7test7test7@proton.me
# 3    SERP_KEY_4  test8test8test8@proton.me
# 4    SERP_KEY_5         test11test11test11
# 5    SERP_KEY_6            test9test9test9
# 6    SERP_KEY_7            test5test5test5
# 7    SERP_KEY_8            test4test4test4
# 8    SERP_KEY_9         test13test13test13
# 9   SERP_KEY_10         test14test14test14
# 10  SERP_KEY_11         test61test61test61
# 11  SERP_KEY_12         test62test62test62
# 12  SERP_KEY_13         test63test63test63
# 13  SERP_KEY_14         test64test64test64
# 14  SERP_KEY_15         test65test65test65
# 15  SERP_KEY_16         test66test66test66
# 16  SERP_KEY_17         test67test67test67
# 17  SERP_KEY_18              test1@msut.me
# 18  SERP_KEY_19              test3@msut.me
# 19  SERP_KEY_20              test4@msut.me
#
# ...

# %%
import os
import sys

# Предполагаем, что ноутбук запущен из корневой папки проекта,
# иначе задайте путь к корневой папке вручную:
ROOT_DIR = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Добавляем корневую папку в sys.path, если её там ещё нет
if ROOT_DIR not in sys.path:
    sys.path.insert(0, ROOT_DIR)

# Формирование полного пути к файлу с ключами
KEYS_PATH = os.path.join(ROOT_DIR, "api_keys_status.xlsx")

# Импортируем APIKeyManager из пакета src
from src.utils.check_serp_response import APIKeyManager

# Инициализируем менеджер ключей и получаем лучший ключ
api_key_manager = APIKeyManager(path_to_file=KEYS_PATH)
best_key_name, best_key = api_key_manager.get_best_api_key()

print("Лучший ключ:", best_key_name, best_key)
# Out:
# /Users/askarembulatov/Digital-Assistant-First/api_keys_status.xlsx
# The best available API key: SERP_KEY_9: 84e42c3faf24a2f4ec9927287675258470df6ee220014e0f6c022b0f4793c678
# Лучший ключ: SERP_KEY_9 84e42c3faf24a2f4ec9927287675258470df6ee220014e0f6c022b0f4793c678
# 2025-02-02 16:50:12,791 - INFO - Running job "check_api_keys (trigger: interval[0:01:00], next run at: 2025-02-02 16:51:12 MSK)" (scheduled at 2025-02-02 16:50:12.786749+03:00)
# 2025-02-02 16:50:17,647 - INFO - Job "check_api_keys (trigger: interval[0:01:00], next run at: 2025-02-02 16:51:12 MSK)" executed successfully
#            Name                      Email  \
# 0    SERP_KEY_1                      test5
# 1    SERP_KEY_2  test6test6test6@proton.me
# 2    SERP_KEY_3  test7test7test7@proton.me
# 3    SERP_KEY_4  test8test8test8@proton.me
# 4    SERP_KEY_5         test11test11test11
# 5    SERP_KEY_6            test9test9test9
# 6    SERP_KEY_7            test5test5test5
# 7    SERP_KEY_8            test4test4test4
# ...

# %%
params = {
    "lr": "1",
    "engine": "yandex",
    "yandex_domain": "yandex.ru",
    "text": "Лучшие рестораны Москвы",
    "api_key": "a307131592b9c88d513848f4bef6ee3ff60236d452a86b528321a554641f6aa0",
}

search = GoogleSearch(params)
results = search.get_dict()
organic_results = results["organic_results"]

# %%
organic_results
# Out:
# [{'position': 1,
#   'title': '10 Лучших ресторанов Москвы 2025 - Tripadvisor',
#   'link': 'https://www.tripadvisor.ru/Restaurants-g298484-zfp10954-Moscow_Central_Russia.html',
#   'displayed_link': 'tripadvisor.ru›Москва›Рестораны Москвы',
#   'snippet': 'Рестораны Москвы, Центрального округа: просмотрите отзывы путешественников Tripadvisor (383 785 шт.) о 15 807 ресторанах Москвы и выполните...'},
#  {'position': 2,
#   'title': 'Лучшие рестораны Москвы 2024 — Афиша–Рестораны',
#   'link': 'https://www.afisha.ru/msk/restaurants/luchshie-restorany-moskvy-2024/',
#   'displayed_link': 'afisha.ru›msk/restaurants/luchshie-restorany-…',
#   'snippet': 'Список «Лучшие рестораны Москвы 2024» – подборка составлена по мнению редакции Афиша-Рестораны.'},
#  {'position': 3,
#   'title': 'Лучшие рестораны в Москве 2025: рейтинг топ-20...',
#   'link': 'https://www.kp.ru/russia/moskva/restorany/',
#   'displayed_link': 'kp.ru›russia/moskva/restorany/',
# ...

# %%
results_with_titles_and_links = [
    (item["title"], item["link"], item["snippet"], item["displayed_link"])
    for item in results.get("organic_results", [])
    if "title" in item and "link" in item
]

# %%
results_with_titles_and_links
# Out:
# [('10 Лучших ресторанов Москвы 2025 - Tripadvisor',
#   'https://www.tripadvisor.ru/Restaurants-g298484-zfp10954-Moscow_Central_Russia.html',
#   'Рестораны Москвы, Центрального округа: просмотрите отзывы путешественников Tripadvisor (383 785 шт.) о 15 807 ресторанах Москвы и выполните...',
#   'tripadvisor.ru›Москва›Рестораны Москвы'),
#  ('Лучшие рестораны Москвы 2024 — Афиша–Рестораны',
#   'https://www.afisha.ru/msk/restaurants/luchshie-restorany-moskvy-2024/',
#   'Список «Лучшие рестораны Москвы 2024» – подборка составлена по мнению редакции Афиша-Рестораны.',
#   'afisha.ru›msk/restaurants/luchshie-restorany-…'),
#  ('Лучшие рестораны в Москве 2025: рейтинг топ-20...',
#   'https://www.kp.ru/russia/moskva/restorany/',
#   'Существуют рейтинги лучших ресторанов в Москве на 2025 год от профессиональных критиков...Со звездами МишленС живой музыкойПанорамныеГрузинские',
#   'kp.ru›russia/moskva/restorany/'),
#  ('Лучшие рестораны в Москве 2024, рестораны рядом со...',
# ...

# %%
q = "Лучшие рестораны Москвы"

params = {
    "q": q,
    #'location': 'Russia',
    "hl": "ru",
    "gl": "ru",
    "google_domain": "google.com",
    "api_key": best_key,
}

search = GoogleSearch(params)
results = search.get_dict()

# %%
results["organic_results"]
# Out:
# [{'position': 1,
#   'title': 'Рейтинг ресторанов Москвы 2025',
#   'link': 'https://www.restoclub.ru/msk/ratings',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.restoclub.ru/msk/ratings&ved=2ahUKEwjoitL9kKWLAxWv3ckDHW0gHf0QFnoECAsQAQ',
#   'displayed_link': 'https://www.restoclub.ru › msk › ratings',
#   'thumbnail': 'https://serpapi.com/searches/679f7830a87cdaa1a8ce2b6c/images/4c2afdf00ba8e38db906b3aac257b8001f80d965cc3f16f8339c380475227000.jpeg',
#   'favicon': 'https://serpapi.com/searches/679f7830a87cdaa1a8ce2b6c/images/4c2afdf00ba8e38db906b3aac257b8005fb7e5bbd02ed5b23466a3ef94c2c72a.png',
#   'snippet': '1 место. Florentini Country Café. Элегантный загородный ресторан от холдинга Gastronomica. 1500; итальянская. 10. Идеально · 2 место. Malakhovka Palace. Нарядный ...',
#   'snippet_highlighted_words': ['1 место. Florentini Country Café'],
#   'sitelinks': {'inline': [{'title': 'Рестораны премиум-класса',
# ...

# %%
from src.internet_search import *

result = search_places("Лучшие рестораны Москвы", best_key)
print(result)
# Out:
# (['1 место. Florentini Country Café. Элегантный загородный ресторан от холдинга Gastronomica. 1500; итальянская. 10. Идеально · 2 место. Malakhovka Palace. Нарядный ...', 'Рестораны Москвы · 1. Ресторан Сабор де ла Вида. (420). Открыто сейчас. Средиземноморская$$$$ Меню · 2. Ресторан White Rabbit. (3 652). Открыто сейчас.', "Лучшие рестораны Москвы · Grand Cru · Mushrooms · Amy Restaurant · Biwon · За крышей · Сахли · 800 Contemporary · Max's Beef for Money. Smart casual.", 'В Москве лучшим баром года стал Butler The Japanese. В номинации «Шеф-повар года» победил Никанор Виейра из Olluco, а «Кондитером года» названа ...', 'Список всех ресторанов в Москве: адреса, описания, отзывы, рейтинг, меню — на официальном сайте Restoclub.ru.', 'Топ-20 лучших ресторанов в Москве по мнению «КП» · «Dr. Живаго» · «Северяне» · «Воронеж» · Selfie · Самые популярные рестораны Москвы · AQ Kitchen · «Пушкинъ» ...', 'Вся информация, чтобы спланировать хороший отдых: кухня, средний чек, рейтинги и отзывы,
# ...
